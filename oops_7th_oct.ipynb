# %%
# 1.Bank Account Create a class representing a bank account with attributes like account number, account holder name, and balance.
#     Implement methods to deposit and withdraw money from the account.

# %%
class BankAccount:
    def __init__(self, account_number, account_holder_name, balance=0.0):
        self.account_number = account_number
        self.account_holder_name = account_holder_name
        self.balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"Deposited ${amount}. New balance: ${self.balance}")
        else:
            print("Invalid deposit amount. Please enter a positive value.")

    def withdraw(self, amount):
        if amount > 0:
            if amount <= self.balance:
                self.balance -= amount
                print(f"Withdrew ${amount}. New balance: ${self.balance}")
            else:
                print("Insufficient funds. Cannot withdraw.")
        else:
            print("Invalid withdrawal amount. Please enter a positive value.")

    def get_balance(self):
        return self.balance

    def display_account_info(self):
        print(f"Account Number: {self.account_number}")
        print(f"Account Holder: {self.account_holder_name}")
        print(f"Balance: ${self.balance}")


# Example usage:
account1 = BankAccount(account_number="123456789", account_holder_name="Kiran", balance=10000.0)
account1.display_account_info()

account1.deposit(500.0)
account1.withdraw(200.0)
account1.display_account_info()
# Out:
# Account Number: 123456789
# Account Holder: Kiran
# Balance: $10000.0
# Deposited $500.0. New balance: $10500.0
# Withdrew $200.0. New balance: $10300.0
# Account Number: 123456789
# Account Holder: Kiran
# Balance: $10300.0

# %%
# 2. Employee Management Create a class representing an employee with attributes like employee ID, name, and salary. 
#    Implement methods to calculate the yearly bonus and display employee details.

# %%
class EmployeeInfo:
    def __init__(self, employeeID, name, salary):
        self.employeeID = employeeID
        self.name = name
        self.salary = salary

    def yearly_bonus(self, annual_salary, bonus_percentage):
        bonus_amount = (bonus_percentage / 100) * annual_salary
        return bonus_amount

    def display_employee_details(self):
        print(f"Employee ID: {self.employeeID}")
        print(f"Name: {self.name}")
        print(f"Salary: {self.salary}")

# Example Usage
employee1 = EmployeeInfo(employeeID="E001", name="John Doe", salary=50000)
employee1.display_employee_details()

bonus_percentage = 5  # Adjust the bonus percentage as needed
bonus_amount = employee1.yearly_bonus(annual_salary=employee1.salary, bonus_percentage=bonus_percentage)
print(f"Yearly Bonus: ${bonus_amount}")
# Out:
# Employee ID: E001
# Name: John Doe
# Salary: 50000
# Yearly Bonus: $2500.0

# %%
# 3.Vehicle Rental Create a class representing a vehicle rental system.Implement methods to rent a vehicle, return a vehicle,
# and display available vehicles.

# %%
class VehicleRentalSystem:
    def __init__(self):
        # Initialize an empty list to store available vehicles
        self.available_vehicles = []

    def rent_vehicle(self, vehicle):
        if vehicle in self.available_vehicles:
            self.available_vehicles.remove(vehicle)
            print(f"Vehicle {vehicle} rented successfully.")
        else:
            print(f"Sorry, {vehicle} is not available for rent.")

    def return_vehicle(self, vehicle):
        self.available_vehicles.append(vehicle)
        print(f"Vehicle {vehicle} returned successfully.")

    def display_available_vehicles(self):
        print("Available Vehicles:")
        for vehicle in self.available_vehicles:
            print(vehicle)

# Example Usage
rental_system = VehicleRentalSystem()

# Add some vehicles to the system
rental_system.available_vehicles.extend(["Car1", "Car2", "Bike1", "Bike2"])

# Display available vehicles
rental_system.display_available_vehicles()

# Rent a vehicle
rental_system.rent_vehicle("Car1")

# Display available vehicles after renting
rental_system.display_available_vehicles()

# Return a vehicle
rental_system.return_vehicle("Car1")

# Display available vehicles after returning
rental_system.display_available_vehicles()
# Out:
# Available Vehicles:
# Car1
# Car2
# Bike1
# Bike2
# Vehicle Car1 rented successfully.
# Available Vehicles:
# Car2
# Bike1
# Bike2
# Vehicle Car1 returned successfully.
# Available Vehicles:
# Car2
# Bike1
# Bike2
# Car1

# %%
#  Library Catalog Create classes representing a library and a book. Implement methods to add books to the library, borrow books,
# and display available books.

# %%
class Book:
    def __init__(self, title, author, book_id):
        self.title = title
        self.author = author
        self.book_id = book_id
        self.is_available = True

    def __str__(self):
        return f"{self.title} by {self.author} (ID: {self.book_id})"

class Library:
    def __init__(self):
        # Initialize an empty list to store available books
        self.available_books = []

    def add_book(self, book):
        self.available_books.append(book)
        print(f"Book '{book.title}' added to the library.")

    def borrow_book(self, book_id):
        for book in self.available_books:
            if book.book_id == book_id and book.is_available:
                book.is_available = False
                print(f"Book '{book.title}' borrowed successfully.")
                return
        print("Book not available for borrowing.")

    def display_available_books(self):
        print("Available Books:")
        for book in self.available_books:
            print(book)

# Example Usage
library = Library()

# Add some books to the library
book1 = Book("The Catcher in the Rye", "J.D. Salinger", 1)
book2 = Book("To Kill a Mockingbird", "Harper Lee", 2)
book3 = Book("1984", "George Orwell", 3)

library.add_book(book1)
library.add_book(book2)
library.add_book(book3)

# Display available books
library.display_available_books()

# Borrow a book
library.borrow_book(2)

# Display available books after borrowing
library.display_available_books()
# Out:
# Book 'The Catcher in the Rye' added to the library.
# Book 'To Kill a Mockingbird' added to the library.
# Book '1984' added to the library.
# Available Books:
# The Catcher in the Rye by J.D. Salinger (ID: 1)
# To Kill a Mockingbird by Harper Lee (ID: 2)
# 1984 by George Orwell (ID: 3)
# Book 'To Kill a Mockingbird' borrowed successfully.
# Available Books:
# The Catcher in the Rye by J.D. Salinger (ID: 1)
# To Kill a Mockingbird by Harper Lee (ID: 2)
# 1984 by George Orwell (ID: 3)

# %%
# 5.Product Inventory Create classes representing a product and an inventory system. Implement methods to add products to the
# inventory, update product quantity, and display available products.

# %%
class Product:
    def __init__(self, product_id, name, price, quantity):
        self.product_id = product_id
        self.name = name
        self.price = price
        self.quantity = quantity

    def __str__(self):
        return f"{self.name} (ID: {self.product_id}, Price: ${self.price}, Quantity: {self.quantity})"

class InventorySystem:
    def __init__(self):
        # Initialize an empty dictionary to store products in the inventory
        self.inventory = {}

    def add_product(self, product):
        if product.product_id not in self.inventory:
            self.inventory[product.product_id] = product
            print(f"Product '{product.name}' added to the inventory.")
        else:
            print(f"Product with ID {product.product_id} already exists in the inventory.")

    def update_quantity(self, product_id, new_quantity):
        if product_id in self.inventory:
            self.inventory[product_id].quantity = new_quantity
            print(f"Quantity for product '{self.inventory[product_id].name}' updated to {new_quantity}.")
        else:
            print(f"Product with ID {product_id} not found in the inventory.")

    def display_available_products(self):
        print("Available Products:")
        for product in self.inventory.values():
            print(product)

# Example Usage
inventory_system = InventorySystem()

# Add some products to the inventory
product1 = Product(product_id=1, name="Laptop", price=800, quantity=10)
product2 = Product(product_id=2, name="Smartphone", price=400, quantity=15)
product3 = Product(product_id=3, name="Headphones", price=50, quantity=30)

inventory_system.add_product(product1)
inventory_system.add_product(product2)
inventory_system.add_product(product3)

# Display available products
inventory_system.display_available_products()

# Update quantity of a product
inventory_system.update_quantity(product_id=2, new_quantity=20)

# Display available products after updating quantity
inventory_system.display_available_products()
# Out:
# Product 'Laptop' added to the inventory.
# Product 'Smartphone' added to the inventory.
# Product 'Headphones' added to the inventory.
# Available Products:
# Laptop (ID: 1, Price: $800, Quantity: 10)
# Smartphone (ID: 2, Price: $400, Quantity: 15)
# Headphones (ID: 3, Price: $50, Quantity: 30)
# Quantity for product 'Smartphone' updated to 20.
# Available Products:
# Laptop (ID: 1, Price: $800, Quantity: 10)
# Smartphone (ID: 2, Price: $400, Quantity: 20)
# Headphones (ID: 3, Price: $50, Quantity: 30)

# %%
# 6.Shape Calculation Create a class representing a shape with attributes like length, width, and height.
# Implement methods to calculate the area and perimeter of the shape.

# %%
import math

class Shape:
    def __init__(self, length=0, width=0, height=0):
        self.length = length
        self.width = width
        self.height = height

    def calculate_area(self):
        raise NotImplementedError("Subclasses must implement this method.")

    def calculate_perimeter(self):
        raise NotImplementedError("Subclasses must implement this method.")

class Rectangle(Shape):
    def calculate_area(self):
        return self.length * self.width

    def calculate_perimeter(self):
        return 2 * (self.length + self.width)

class Square(Rectangle):
    def __init__(self, side):
        super().__init__(length=side, width=side)

class Triangle(Shape):
    def calculate_area(self):
        # Using Heron's formula for the area of a triangle
        s = (self.length + self.width + self.height) / 2
        return math.sqrt(s * (s - self.length) * (s - self.width) * (s - self.height))

    def calculate_perimeter(self):
        return self.length + self.width + self.height

# Example Usage
rectangle = Rectangle(length=5, width=3)
print("Rectangle:")
print(f"Area: {rectangle.calculate_area()}")
print(f"Perimeter: {rectangle.calculate_perimeter()}")

square = Square(side=4)
print("\nSquare:")
print(f"Area: {square.calculate_area()}")
print(f"Perimeter: {square.calculate_perimeter()}")

triangle = Triangle(length=3, width=4, height=5)
print("\nTriangle:")
print(f"Area: {triangle.calculate_area()}")
print(f"Perimeter: {triangle.calculate_perimeter()}")
# Out:
# Rectangle:
# Area: 15
# Perimeter: 16
#
# Square:
# Area: 16
# Perimeter: 16
#
# Triangle:
# Area: 6.0
# Perimeter: 12

# %%
# 7.Student Management Create a class representing a student with attributes like student ID, name, and grades.
# Implement methods to calculate the average grade and display student details.

# %%
class Student:
    def __init__(self, student_id, name, grades=None):
        self.student_id = student_id
        self.name = name
        self.grades = grades or []

    def add_grade(self, grade):
        self.grades.append(grade)
        print(f"Grade {grade} added for student {self.name}.")

    def calculate_average_grade(self):
        if not self.grades:
            return 0  # Avoid division by zero if there are no grades
        return sum(self.grades) / len(self.grades)

    def display_student_details(self):
        print("Student Details:")
        print(f"Student ID: {self.student_id}")
        print(f"Name: {self.name}")
        print("Grades:", self.grades)
        print(f"Average Grade: {self.calculate_average_grade():.2f}")

# Example Usage
student1 = Student(student_id="S001", name="John Doe", grades=[85, 90, 78, 92])
student2 = Student(student_id="S002", name="Jane Smith")

# Add grades for student2
student2.add_grade(88)
student2.add_grade(75)
student2.add_grade(90)

# Display student details
student1.display_student_details()
print("\n")
student2.display_student_details()
# Out:
# Grade 88 added for student Jane Smith.
# Grade 75 added for student Jane Smith.
# Grade 90 added for student Jane Smith.
# Student Details:
# Student ID: S001
# Name: John Doe
# Grades: [85, 90, 78, 92]
# Average Grade: 86.25
#
#
# Student Details:
# Student ID: S002
# Name: Jane Smith
# Grades: [88, 75, 90]
# Average Grade: 84.33

# %%
# 8.Email Management Create a class representing an email with attributes like sender, recipient, and subject.
# Implement methods to send an email and display email details.

# %%
class Email:
    def __init__(self, sender, recipient, subject, body):
        self.sender = sender
        self.recipient = recipient
        self.subject = subject
        self.body = body
        self.is_sent = False

    def send_email(self):
        if not self.is_sent:
            print(f"Email sent from {self.sender} to {self.recipient}.")
            self.is_sent = True
        else:
            print("This email has already been sent.")

    def display_email_details(self):
        print("Email Details:")
        print(f"Sender: {self.sender}")
        print(f"Recipient: {self.recipient}")
        print(f"Subject: {self.subject}")
        print("Body:")
        print(self.body)
        print(f"Status: {'Sent' if self.is_sent else 'Draft'}")

# Example Usage
email1 = Email(sender="john@example.com", recipient="jane@example.com", subject="Meeting Tomorrow", body="Hi Jane, let's meet tomorrow at 2 PM.")
email2 = Email(sender="jane@example.com", recipient="john@example.com", subject="Re: Meeting Tomorrow", body="Hi John, sure, let's meet at the suggested time.")

# Display email details (before sending)
email1.display_email_details()
print("\n")
email2.display_email_details()
print("\n")

# Send email
email1.send_email()
print("\n")

# Display email details (after sending)
email1.display_email_details()
# Out:
# Email Details:
# Sender: john@example.com
# Recipient: jane@example.com
# Subject: Meeting Tomorrow
# Body:
# Hi Jane, let's meet tomorrow at 2 PM.
# Status: Draft
#
#
# Email Details:
# Sender: jane@example.com
# Recipient: john@example.com
# Subject: Re: Meeting Tomorrow
# Body:
# Hi John, sure, let's meet at the suggested time.
# Status: Draft
#
#
# Email sent from john@example.com to jane@example.com.
#
#
# Email Details:
# Sender: john@example.com
# Recipient: jane@example.com
# Subject: Meeting Tomorrow
# Body:
# Hi Jane, let's meet tomorrow at 2 PM.
# Status: Sent

# %%
# 9.Social Media Profile Create a class representing a social media profile with attributes like username and posts.
# Implement methods to add posts, display posts, and search for posts by keyword.

# %%
class SocialMediaProfile:
    def __init__(self, username):
        self.username = username
        self.posts = []

    def add_post(self, content):
        post = {"content": content, "author": self.username}
        self.posts.append(post)
        print(f"Post added to {self.username}'s profile.")

    def display_posts(self):
        print(f"Posts from {self.username}'s profile:")
        for i, post in enumerate(self.posts, start=1):
            print(f"{i}. {post['content']} - by {post['author']}")

    def search_posts_by_keyword(self, keyword):
        matching_posts = [post for post in self.posts if keyword.lower() in post['content'].lower()]
        if matching_posts:
            print(f"Posts containing '{keyword}':")
            for i, post in enumerate(matching_posts, start=1):
                print(f"{i}. {post['content']} - by {post['author']}")
        else:
            print(f"No posts containing '{keyword}' found.")

# Example Usage
profile1 = SocialMediaProfile(username="john_doe")
profile2 = SocialMediaProfile(username="jane_smith")

# Add posts to profiles
profile1.add_post("Enjoying a sunny day at the beach!")
profile1.add_post("Just had a delicious dinner at my favorite restaurant.")

profile2.add_post("Exploring new hiking trails.")
profile2.add_post("Finished reading a great book.")

# Display posts from profiles
profile1.display_posts()
print("\n")
profile2.display_posts()
print("\n")

# Search for posts by keyword
profile1.search_posts_by_keyword("dinner")
print("\n")
profile2.search_posts_by_keyword("hiking")
# Out:
# Post added to john_doe's profile.
# Post added to john_doe's profile.
# Post added to jane_smith's profile.
# Post added to jane_smith's profile.
# Posts from john_doe's profile:
# 1. Enjoying a sunny day at the beach! - by john_doe
# 2. Just had a delicious dinner at my favorite restaurant. - by john_doe
#
#
# Posts from jane_smith's profile:
# 1. Exploring new hiking trails. - by jane_smith
# 2. Finished reading a great book. - by jane_smith
#
#
# Posts containing 'dinner':
# 1. Just had a delicious dinner at my favorite restaurant. - by john_doe
#
#
# Posts containing 'hiking':
# 1. Exploring new hiking trails. - by jane_smith

# %%
# 10.ToDo List Create a class representing a ToDo list with attributes like tasks and due dates.Implement methods to add tasks, 
# mark tasks as completed, and display pending tasks.

# %%
class ToDoList:
    def __init__(self):
        self.tasks = []

    def add_task(self, task, due_date):
        new_task = {"task": task, "due_date": due_date, "completed": False}
        self.tasks.append(new_task)
        print(f"Task '{task}' added to the ToDo list.")

    def mark_task_completed(self, task):
        for t in self.tasks:
            if t["task"] == task:
                t["completed"] = True
                print(f"Task '{task}' marked as completed.")
                return
        print(f"Task '{task}' not found in the ToDo list.")

    def display_pending_tasks(self):
        pending_tasks = [task for task in self.tasks if not task["completed"]]
        if pending_tasks:
            print("Pending Tasks:")
            for i, task in enumerate(pending_tasks, start=1):
                print(f"{i}. {task['task']} - Due on: {task['due_date']}")
        else:
            print("No pending tasks in the ToDo list.")

# Example Usage
todo_list = ToDoList()

# Add tasks to the ToDo list
todo_list.add_task("Finish project report", "2023-01-15")
todo_list.add_task("Buy groceries", "2023-01-20")
todo_list.add_task("Exercise for 30 minutes", "2023-01-18")

# Display pending tasks
todo_list.display_pending_tasks()
print("\n")

# Mark a task as completed
todo_list.mark_task_completed("Exercise for 30 minutes")

# Display pending tasks after marking one as completed
todo_list.display_pending_tasks()
# Out:
# Task 'Finish project report' added to the ToDo list.
# Task 'Buy groceries' added to the ToDo list.
# Task 'Exercise for 30 minutes' added to the ToDo list.
# Pending Tasks:
# 1. Finish project report - Due on: 2023-01-15
# 2. Buy groceries - Due on: 2023-01-20
# 3. Exercise for 30 minutes - Due on: 2023-01-18
#
#
# Task 'Exercise for 30 minutes' marked as completed.
# Pending Tasks:
# 1. Finish project report - Due on: 2023-01-15
# 2. Buy groceries - Due on: 2023-01-20
